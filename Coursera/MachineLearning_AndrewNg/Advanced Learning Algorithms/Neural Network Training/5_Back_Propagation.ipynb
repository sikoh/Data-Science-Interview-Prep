# %% [markdown]
# # What is a derivative?
# - Tensorflow can specify a neural network architecture to compute the output y as a function of the input x, and also a specify a cost function, and Tensorflow will then automatically use back propagation to compute derivatives and use gradient descent or Adam to train the parameters of a neural network.
# - The backpropagation algorithm, which computes derivaties of our cost function with respective to the parameters, is a key algorithm in neural network learning.
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Computation Graph
# - The computation graph is a key idea in deep learning, and it is also how programming frameworks like Tensorflow, automatic compute derivatives of our neural networks.
# - To build up a computation graph in which the steps we need to compute the cause function J are broken down into smaller steps.
# - ![image.png](attachment:image.png)
# -

# %% [markdown]
# ![Screenshot 2024-06-18 at 4.25.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Larger Neural Network
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
